# %%
import requests
import pandas as pd

# %%
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 23:
    headers = {
        'authority': 'www.carrefour.ke',
        'accept': '*/*',
        'accept-language': 'en-US,en;q=0.9',
        'appid': 'Reactweb',
        'credentials': 'include',
        'deviceid': '1664466798.1699538704',
        'env': 'prod',
        'intent': 'STANDARD',
        'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6ImZmZTRiMTQ5ZTMxNDlmMzUiLCJ0ciI6IjJhOTEyNzlhMjBhMTI4MzQyNGMxM2E1MGIwMzkyNjQ5IiwidGkiOjE2OTk1Mzg4Nzg2ODZ9fQ==',
        'referer': 'https://www.carrefour.ke/mafken/en/c/FKEN1600000',
        'sec-fetch-dest': 'empty',
        'sec-fetch-mode': 'cors',
        'sec-fetch-site': 'same-origin',
        'storeid': 'mafken',
        'token': 'undefined',
        'traceparent': '00-2a91279a20a1283424c13a50b0392649-ffe4b149e3149f35-01',
        'tracestate': '3355720@nr=0-1-3355720-1021845705-ffe4b149e3149f35----1699538878686',
        'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
        'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
    }

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get('https://www.carrefour.ke/api/v8/categories/FKEN1600000', params=params, headers=headers)
    
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('fastFood.xlsx', index=False)

# %%
# fruits 
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 5:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=lorfo8cu&sl=0&tt=0"; JSESSIONID=689111773E4E0850C95205F9F7925CEE.accstorefront-b44488df6-vfwkz; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699551086999$sn:2$en:2$s:1699549140851%3Bexp-sess; _ga=GA1.2.1664466798.1699538704; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Nov+09+2023+20%3A01%3A28+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; _ga_BWW6C6N1ZH=GS1.1.1699549110.4.1.1699549313.39.0.0; _gat_UA-125827987-20=1',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6IjZlYTQ5MTQ1OTNjNjI1NTYiLCJ0ciI6IjczMjViOGRmMWU0OTAwNzE5ZTkyZGYwMWRkM2E2MjA0IiwidGkiOjE2OTk1NDk0MDc4NTh9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/FKEN1660000',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-7325b8df1e4900719e92df01dd3a6204-6ea4914593c62556-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-6ea4914593c62556----1699549407858',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get('https://www.carrefour.ke/api/v8/categories/FKEN1660000', params=params, cookies=cookies, headers=headers)

        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('fruits.xlsx', index=False)

# %%
# Juices 
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 8:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=lorfo8cu&sl=0&tt=0"; JSESSIONID=689111773E4E0850C95205F9F7925CEE.accstorefront-b44488df6-vfwkz; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699551884844$sn:2$en:5$s:1699549140851%3Bexp-sess; OptanonConsent=isGpcEnabled=0&datestamp=Thu+Nov+09+2023+20%3A14%3A46+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; _ga=GA1.2.1664466798.1699538704; _gat_UA-125827987-20=1; _ga_BWW6C6N1ZH=GS1.1.1699549110.4.1.1699550137.52.0.0',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6IjFkMzhiMmRkNDhiYmMwNWMiLCJ0ciI6IjQ1Mzc3ZDgxYzMwMWE2YzI1NmFkM2RlMTFlYWQwMmU4IiwidGkiOjE2OTk1NTAxNTU5MDV9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/FKEN1520000',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-45377d81c301a6c256ad3de11ead02e8-1d38b2dd48bbc05c-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-1d38b2dd48bbc05c----1699550155905',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get('https://www.carrefour.ke/api/v8/categories/FKEN1520000', params=params, cookies=cookies, headers=headers)


        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('juices.xlsx', index=False)

# %%
# soft drinks
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 6:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; AKA_A2=A; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=losfkx4n&sl=0&tt=0"; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699611295851$sn:3$en:2$s:1699609452815%3Bexp-sess; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Nov+10+2023+12%3A45%3A01+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _gat_UA-125827987-20=1; _ga=GA1.2.1664466798.1699538704; JSESSIONID=3EDE781442A53934B4082179F54BDEE2.accstorefront-b44488df6-vfwkz; _ga_BWW6C6N1ZH=GS1.1.1699609453.5.1.1699609544.37.0.0',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6Ijg0NmI2NmM0YzJiZGU5ZjMiLCJ0ciI6IjYyNjRhZjQ0MDU2OWM0N2UxODAyNGYyYzg4OWE3ZWE2IiwidGkiOjE2OTk2MDk1NTI2NjV9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/FKEN1550000',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-6264af440569c47e18024f2c889a7ea6-846b66c4c2bde9f3-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-846b66c4c2bde9f3----1699609552665',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get('https://www.carrefour.ke/api/v8/categories/FKEN1550000', params=params, headers=headers)


        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('softDrinks.xlsx', index=False)

# %%
# tea
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 6:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; AKA_A2=A; JSESSIONID=3EDE781442A53934B4082179F54BDEE2.accstorefront-b44488df6-vfwkz; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=losfkx4n&sl=1&tt=4du&rl=1"; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699612033137$sn:3$en:4$s:1699609452815%3Bexp-sess; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Nov+10+2023+12%3A57%3A15+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; _ga=GA1.2.1664466798.1699538704; _gat_UA-125827987-20=1; _ga_BWW6C6N1ZH=GS1.1.1699609453.5.1.1699610257.60.0.0',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6IjU0M2JlODk3NDM3NWZiMWYiLCJ0ciI6ImVmYjI5MjM4ZTU1ZWQ2NDExMDQ5ZDRjZDYzNGQxZjRlIiwidGkiOjE2OTk2MTAyNzMwMjF9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/FKEN1560000',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-efb29238e55ed6411049d4cd634d1f4e-543be8974375fb1f-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-543be8974375fb1f----1699610273021',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get('https://www.carrefour.ke/api/v8/categories/FKEN1560000', params=params, headers=headers)


        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('tea.xlsx', index=False)

# %%
# coffee
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 6:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; AKA_A2=A; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=losg1m2n&sl=1&tt=83g"; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699613548207$sn:3$en:7$s:1699609452815%3Bexp-sess; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Nov+10+2023+13%3A22%3A28+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; JSESSIONID=5AA6C455B10B391F32B5A206FAD958B5.accstorefront-b44488df6-vfwkz; _ga=GA1.2.1664466798.1699538704; _gat_UA-125827987-20=1; _ga_BWW6C6N1ZH=GS1.1.1699609453.5.1.1699611794.52.0.0',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6IjgxYmRiMmJkNGQwYzBlMGQiLCJ0ciI6IjU4NmMxMWEyMzUyZTE2OWRhMjM5YmFlZGU3NDk1MGJkIiwidGkiOjE2OTk2MTE3OTg0NjZ9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/FKEN1510000',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-586c11a2352e169da239baede74950bd-81bdb2bd4d0c0e0d-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-81bdb2bd4d0c0e0d----1699611798466',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get('https://www.carrefour.ke/api/v8/categories/FKEN1510000', params=params, headers=headers)


        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('coffee.xlsx', index=False)

# %%
# water
# coffee
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 6:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=loshffvv&sl=0&tt=0"; AKA_A2=A; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699615118367$sn:3$en:16$s:1699609452815%3Bexp-sess; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Nov+10+2023+13%3A48%3A39+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _ga=GA1.2.1664466798.1699538704; JSESSIONID=A3491E5A61CE1C561A16740458D40206.accstorefront-b44488df6-vfwkz; _gat_UA-125827987-20=1; _ga_BWW6C6N1ZH=GS1.1.1699609453.5.1.1699613357.52.0.0',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6ImQwNTY2ZjMxMzc0ZjBjMWEiLCJ0ciI6IjVhZTA1NDc3YWFmODI4YzAyZjIyOWU0MDU2OWVmMGZjIiwidGkiOjE2OTk2MTMzNjIwNzV9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/FKEN1570000',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-5ae05477aaf828c02f229e40569ef0fc-d0566f31374f0c1a-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-d0566f31374f0c1a----1699613362075',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get('https://www.carrefour.ke/api/v8/categories/FKEN1570000', params=params, headers=headers)


        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('water.xlsx', index=False)

# %%
# powered drinks
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 6:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=loshffvv&sl=0&tt=0"; AKA_A2=A; JSESSIONID=A3491E5A61CE1C561A16740458D40206.accstorefront-b44488df6-vfwkz; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699615363287$sn:3$en:18$s:1699609452815%3Bexp-sess; _ga=GA1.2.1664466798.1699538704; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Nov+10+2023+13%3A52%3A44+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; _ga_BWW6C6N1ZH=GS1.1.1699609453.5.1.1699613592.4.0.0; _gat_UA-125827987-20=1',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6IjIzYTJmMzYyZWViZGVhNTMiLCJ0ciI6IjdmZTExZTg2ZjIwMTMyODY0OGQ3MDc1MDUzZWZiZDMxIiwidGkiOjE2OTk2MTM2MDkwNzB9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/FKEN1540000',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-7fe11e86f201328648d7075053efbd31-23a2f362eebdea53-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-23a2f362eebdea53----1699613609070',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get('https://www.carrefour.ke/api/v8/categories/FKEN1540000', params=params, headers=headers)


        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('poweredDrink.xlsx', index=False)

# %%
# powered drinks
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 17:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=loshffvv&sl=0&tt=0"; AKA_A2=A; JSESSIONID=A3491E5A61CE1C561A16740458D40206.accstorefront-b44488df6-vfwkz; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699615899037$sn:3$en:22$s:1699609452815%3Bexp-sess; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Nov+10+2023+14%3A01%3A39+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _ga=GA1.2.1664466798.1699538704; _gat_UA-125827987-20=1; _ga_BWW6C6N1ZH=GS1.1.1699609453.5.1.1699614553.52.0.0',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6IjI5ZDMwZTc3NmVjOTYwNDYiLCJ0ciI6IjhiOTE5ODQ3ZTZiNWY1MDQzMDkwNGVmODI5ODZiMzhiIiwidGkiOjE2OTk2MTQ1NTgxMTh9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/NFKEN3020000',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-8b919847e6b5f50430904ef82986b38b-29d30e776ec96046-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-29d30e776ec96046----1699614558118',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get(
        'https://www.carrefour.ke/api/v8/categories/NFKEN3020000',
        params=params,
        
        headers=headers,
    )

        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('cleaningSupplies.xlsx', index=False)

# %%
# cleaning and household
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 35:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; AKA_A2=A; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699617364720$sn:3$en:23$s:1699609452815%3Bexp-sess; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Nov+10+2023+14%3A26%3A09+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; _ga=GA1.2.1664466798.1699538704; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=losj7qu8&sl=0&tt=0&ld=1sp6g&nu=9y8m6cy&cl=1c9h"; JSESSIONID=4DDBCF48FDB9BE3BD7965C7A9D7C0E90.accstorefront-b44488df6-vfwkz; _gat_UA-125827987-20=1; _ga_BWW6C6N1ZH=GS1.1.1699609453.5.1.1699615665.55.0.0',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6IjBmMGM1NmQ5NGU3ZjI5NzMiLCJ0ciI6IjAyOGE2MTM0N2YyYjIxMTUyM2Y2MGJhNzI0ZDdmMjJlIiwidGkiOjE2OTk2MTU2NzI1OTl9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/NFKEN3000000?currentPage=0&filter=&nextPageOffset=0&pageSize=60&sortBy=relevance',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-028a61347f2b211523f60ba724d7f22e-0f0c56d94e7f2973-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-0f0c56d94e7f2973----1699615672599',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get(
        'https://www.carrefour.ke/api/v8/categories/NFKEN3000000',
        params=params,
        
        headers=headers,
    )

        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('cleaningHouseHold.xlsx', index=False)

# %%
# baby products
# cleaning and household
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 35:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; AKA_A2=A; JSESSIONID=4DDBCF48FDB9BE3BD7965C7A9D7C0E90.accstorefront-b44488df6-vfwkz; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=losj7qu8&sl=1&tt=0&obo=1&rl=1"; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699617904909$sn:3$en:25$s:1699609452815%3Bexp-sess; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Nov+10+2023+14%3A35%3A06+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; _ga=GA1.2.1664466798.1699538704; _gat_UA-125827987-20=1; _ga_BWW6C6N1ZH=GS1.1.1699609453.5.1.1699616203.41.0.0',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6IjM4NmRmOWE2YjdkMTU4ZjciLCJ0ciI6ImJkZjE2YWM1ZmIzYzc5MTgzMTM2MjkyN2UwY2YzODc3IiwidGkiOjE2OTk2MTYyMDcwMzd9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/FKEN1020000?currentPage=0&filter=&nextPageOffset=0&pageSize=60&sortBy=relevance',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-bdf16ac5fb3c791831362927e0cf3877-386df9a6b7d158f7-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-386df9a6b7d158f7----1699616207037',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get('https://www.carrefour.ke/api/v8/categories/FKEN1020000', params=params, headers=headers)


        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('babyProducts.xlsx', index=False)

# %%
# bio and organic food
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 35:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; AKA_A2=A; JSESSIONID=4DDBCF48FDB9BE3BD7965C7A9D7C0E90.accstorefront-b44488df6-vfwkz; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=losj7qu8&sl=2&tt=8qw&obo=1&rl=1"; _ga=GA1.2.1664466798.1699538704; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699618316901$sn:3$en:26$s:1699609452815%3Bexp-sess; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Nov+10+2023+14%3A41%3A57+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _gat_UA-125827987-20=1; _ga_BWW6C6N1ZH=GS1.1.1699609453.5.1.1699616615.57.0.0',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6ImVmYjczNDU1ODE3YzNmMjEiLCJ0ciI6ImNiNDc3MDlkZjhhNzhiYjI4MTlmYTg0OGI4MGEyMDNhIiwidGkiOjE2OTk2MTY2MjA4MzB9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/FKEN1200000',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-cb47709df8a78bb2819fa848b80a203a-efb73455817c3f21-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-efb73455817c3f21----1699616620830',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get('https://www.carrefour.ke/api/v8/categories/FKEN1200000', params=params, headers=headers)


        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            name.append(result['name'])
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_excel('bioOrganicFood.xlsx', index=False)

# %%
# face body skin care
import requests
import pandas as pd

merged_df = pd.DataFrame()

i = 0

while i < 35:
    headers = {
    'authority': 'www.carrefour.ke',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'appid': 'Reactweb',
    # 'cookie': 'maf-session-id=A663EE45-CAE4-CDBF-0581-505522D99183; storeInfo=mafken|en|KES; mafken-preferred-delivery-area=Westlands - Nairobi; prevAreaCode=Westlands - Nairobi; cart_api=v2; _gcl_au=1.1.913131082.1699538703; _gid=GA1.2.814879989.1699538704; _scid=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; _fbp=fb.1.1699538705447.148586538; _sctr=1%7C1699477200000; app_version=v4; page_type=undefined; cto_bundle=; OptanonAlertBoxClosed=2023-11-09T14:06:21.093Z; mafken-web-preferred-delivery-area="Westlands - Nairobi"; ROUTE=.accstorefront-b44488df6-vfwkz; RT="z=1&dm=www.carrefour.ke&si=f7cdfe87-c92b-496a-82ba-29000e225f65&ss=losj7qu8&sl=4&tt=mkh&obo=1&rl=1"; _ga=GA1.2.1664466798.1699538704; TEAL=v:818bb466980b63830357280063812576f4723672856$t:1699619603153$sn:3$en:28$s:1699609452815%3Bexp-sess; _scid_r=e5ca364d-df36-4d2c-9b3a-2ff411f4019f; OptanonConsent=isGpcEnabled=0&datestamp=Fri+Nov+10+2023+15%3A03%3A24+GMT%2B0300+(East+Africa+Time)&version=202301.2.0&isIABGlobal=false&hosts=&consentId=31aac3ab-3185-4f6f-8a3e-9e48cae2c8bb&interactionCount=2&landingPath=NotLandingPage&groups=C0004%3A1%2CC0001%3A1%2CC0002%3A1%2CC0003%3A1&AwaitingReconsent=false&geolocation=KE%3B30; JSESSIONID=E032BA157F83000C8687BC8374A72A89.accstorefront-b44488df6-vfwkz; _gat_UA-125827987-20=1; _ga_BWW6C6N1ZH=GS1.1.1699609453.5.1.1699617859.50.0.0',
    'credentials': 'include',
    'deviceid': '1664466798.1699538704',
    'env': 'prod',
    'intent': 'STANDARD',
    'newrelic': 'eyJ2IjpbMCwxXSwiZCI6eyJ0eSI6IkJyb3dzZXIiLCJhYyI6IjMzNTU3MjAiLCJhcCI6IjEwMjE4NDU3MDUiLCJpZCI6IjQ0MzM4ODIxNzY5NDIwODAiLCJ0ciI6ImQ1NDlhZjIxOTNmYzVlMjUwZTQyM2ExNDZmNTUzYzYzIiwidGkiOjE2OTk2MTc4NjgyNjF9fQ==',
    'referer': 'https://www.carrefour.ke/mafken/en/c/NFKEN2020000?currentPage=0&filter=&nextPageOffset=0&pageSize=60&sortBy=relevance',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'storeid': 'mafken',
    'token': 'undefined',
    'traceparent': '00-d549af2193fc5e250e423a146f553c63-4433882176942080-01',
    'tracestate': '3355720@nr=0-1-3355720-1021845705-4433882176942080----1699617868261',
    'user-agent': 'Mozilla/5.0 (iPhone; CPU iPhone OS 16_6 like Mac OS X) AppleWebKit/605.1.15 (KHTML, like Gecko) Version/16.6 Mobile/15E148 Safari/604.1',
    'userid': 'A663EE45-CAE4-CDBF-0581-505522D99183',
}

    params = {
        'filter': '',
        'sortBy': 'relevance',
        'currentPage': str(i),
        'pageSize': '60',
        'maxPrice': '',
        'minPrice': '',
        'areaCode': 'Westlands - Nairobi',
        'lang': 'en',
        'displayCurr': 'KES',
        'latitude': '-1.2672236834605626',
        'longitude': '36.810586556760555',
        'needVariantsData': 'true',
        'nextOffset': '',
        'responseWithCatTree': 'true',
        'depth': '3',
    }

    response = requests.get(
        'https://www.carrefour.ke/api/v8/categories/NFKEN2020000',
        params=params,
        
        headers=headers,
    )

        
    if response.status_code == 200:
        results_json = response.json()
        result_items = results_json['products']
        
        name = []
        category = []
        type = []
        price = []
        brand = []

        for result in result_items:
            product_name=result['name'].replace(':','_')

            # if any(char in product_name for char in '/\\?*[]:'):
            #     print(f"Problematic product name: {product_name}")

            name.append(product_name)
            brand.append(result['brand']['name'])
            price.append(result['price']['price'])
            type.append(result['type'])
            category.append(result['category'][0]['name'])

        carefor_df = pd.DataFrame({'name': name, 'brand': brand, 'price': price, 'type': type, 'category': category})
        # carefor_df.to_excel(f'file{i}.xlsx', index=False)
        
        # Append the current DataFrame to the merged DataFrame
        merged_df = pd.concat([merged_df, carefor_df], ignore_index=True)
        
        i += 1
    else:
        print(f"Error in request for page {i}: {response.status_code}")

# Save the merged DataFrame to a single Excel file
merged_df.to_csv('faceBodySkinCare.csv', index=False, escapechar='\\')

# %%
results_json=response.json()

# %%
results_json.keys()
# Out:
# dict_keys(['products', 'facets', 'filters', 'totalProducts', 'numOfPages', 'breadCrumb', 'pagination', 'sorts', 'posInfo', 'title', 'is_food_category', 'algoliaQueryID', 'queryCategorizationTree'])

# %%
result_items=results_json['products']

# %%
len(result_items)
# Out:
# 55

# %%
# name
result_items[0]['name']
# Out:
# 'Farmer&#39;s Choice Spicy Beef Sausage 1Kg'

# %%
# category
result_items[0]['category'][0]['name']
# Out:
# 'Fresh Food'

# %%
# type
result_items[0]['type']
# Out:
# 'FOOD'

# %%
# price
result_items[0]['price']['price']
# Out:
# 768

# %%
# brand
result_items[0]['brand']['name']
# Out:
# "FARMER'S CHOICE"

# %%
name=[]
category=[]
type=[]
price=[]
brand=[]

for result in result_items:
    # name
    name.append(result['name'])
    # brand
    brand.append(result['brand']['name'])
    # price
    price.append(result['price']['price'])
    # type
    type.append(result['type'])
    # category
    category.append(result['category'][0]['name'])

# %%
carefor_df=pd.DataFrame({'name':name,'brand':brand,'price':price,'type':type,'category':category})

# %%
carefor_df
# Out:
#                                                  name                 brand  \
# 0          Farmer&#39;s Choice Spicy Beef Sausage 1Kg       FARMER'S CHOICE
# 1                         Sirimon Cheddar Cheese 500G               SIRIMON
# 2             Laki laki greek yoghurt blueberry 150ml           LP - NONAME
# 3          Ilara Thick And Creamy Plain Yoghurt 250ml                 ILARA
# 4                      Bio Semi Skimmed Fresh Milk 1L                   BIO
# 5                            Sirimon Feta Cheese 250G               SIRIMON
# 6                           LATO UHT TETRA PACK 125ML                  LATO
# 7        Brookside Farm Fresh Cooking Cream Cup 400ml             BROOKSIDE
# 8                              Beef Kenyan Stroganoff                  None
# 9     Ilara Thick And Creamy Strawberry Yoghurt 250ml                 ILARA
# 10                 BIO yoghurt assorted pack 150ml X6                   BIO
# ...
